# %%
from langchain.llms import OpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# llm=OpenAI(temperature=0.6)
import os
llm=OpenAI(openai_api_key=os.getenv("OPENAI_API"),temperature=0.6)
# Out:
# C:\Users\Harshit Goswami\AppData\Local\Temp\ipykernel_14256\2141339548.py:3: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm=OpenAI(openai_api_key=os.getenv("OPENAI_API"),temperature=0.6)

# %% [markdown]
# temperature value -> how creative we want our model
#
# 0 -> it means model is very safe it is not taking any bets
#
# 1 -> it will take risk it might generate wrong output

# %%
text='What is capital of india'
print(llm.predict(text))
# Out:
# C:\Users\Harshit Goswami\AppData\Local\Temp\ipykernel_14256\1372991789.py:2: LangChainDeprecationWarning: The method `BaseLLM.predict` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   print(llm.predict(text))
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 text='What is capital of india'
# ----> 2 print(llm.predict(text))
#
# File c:\Users\Harshit Goswami\OneDrive\Langchain\Q-A-Chatbot_using_Langchain\venv\lib\site-packages\langchain_core\_api\deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# ...

# %%
# from langchain import HuggingFaceHub
from langchain_community.llms import HuggingFaceHub  # Correct import
llm_huggingface = HuggingFaceHub(
    repo_id="deepseek-ai/DeepSeek-R1",  # Explicitly specify the model
    # task="text2text-generation",     # Explicitly specify the task
    huggingfacehub_api_token=os.getenv("HUGGINGFACE_API"),  # API key
    model_kwargs={"temperature": 0.6, "max_length": 64}  # Model parameters
)

# %%
output=llm_huggingface("can you tell me the capital of Russia?")
print(output)
# Out:
# c:\Users\Harshit Goswami\OneDrive\Langchain\Q-A-Chatbot_using_Langchain\venv\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %% [markdown]
# ## Prompt Templates

# %%
from langchain.prompts import PromptTemplate
prompt_template=PromptTemplate(input_variables=["country"],
                       template="tell me capital of {country}" 
                               )

prompt_template.format(country='India')
# Out:
# 'tell me capital of India'

# %%
from langchain.chains import LLMChain
chain=LLMChain(llm=llm_huggingface,prompt=prompt_template)
chain.run("India")
# Out:
# C:\Users\Harshit Goswami\AppData\Local\Temp\ipykernel_14152\1782981766.py:2: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain=LLMChain(llm=llm_huggingface,prompt=prompt_template)
# C:\Users\Harshit Goswami\AppData\Local\Temp\ipykernel_14152\1782981766.py:3: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain.run("India")
# ...

# %% [markdown]
# ## Combining multiple chain with simple Sequential chain

# %%
capital_template=PromptTemplate(input_variables=["country"],
                                template="tell me capital of {country}"
                                )
capital_chain=LLMChain(llm=llm_huggingface,prompt=capital_template)

famous_template=PromptTemplate(input_variables=["capital"],
                               template="suggest some amazing places to visit in {capital}"
                               )
famous_chain=LLMChain(llm=llm_huggingface,prompt=famous_template)

# %%
from langchain.chains import SimpleSequentialChain
chain=SimpleSequentialChain(chains=[capital_chain,famous_chain])
chain.run("India")
# Out:
# c:\Users\Harshit Goswami\OneDrive\Langchain\Q-A-Chatbot_using_Langchain\venv\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %% [markdown]
# ## Sequential Chain

# %%
capital_template=PromptTemplate(input_variables=['country'],
                                template="tell me capital of{country}",
                                )
capital_chain=LLMChain(llm=llm_huggingface,prompt=capital_template,output_key="capital")

famous_template=PromptTemplate(input_variables=["capital"],
                               template="suggest me some famous places of {capital}"
                               )
famous_chain=LLMChain(llm=llm_huggingface,prompt=famous_template,output_key="places")

# %%
from langchain.chains import SequentialChain
chain=SequentialChain(chains=[capital_chain,famous_chain],
                      input_variables=['country'],
                      output_variables=['capital',"places"]
                      )

# from langchain.chains import SequentialChain
# chain=SequentialChain(chains=[capital_chain,famous_chain],
# input_variables=['country'],
# output_variables=['capital',"places"])

# %%
chain({"country":"India"})
# Out:
# c:\Users\Harshit Goswami\OneDrive\Langchain\Q-A-Chatbot_using_Langchain\venv\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %% [markdown]
# ## Chatmodels With ChatOpenAI

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain.schema import HumanMessage,SystemMessage,AIMessage

# %%
chatllm=ChatOpenAI(openai_api_key=os.getenv('OPENAI_API'),temperature=0.6,model='gpt-3.5-turbo')
# Out:
# C:\Users\Harshit Goswami\AppData\Local\Temp\ipykernel_14152\1168056299.py:1: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   chatllm=ChatOpenAI(openai_api_key=os.environ['OPENAI_API_KEY'],temperature=0.6,model='gpt-3.5-turbo')

# %%
chatllm([
    SystemMessage(content="you are a comedian AI assistant"),
    HumanMessage(content="please provide some comedy punch lines")
])
# Out:
# C:\Users\Harshit Goswami\AppData\Local\Temp\ipykernel_14152\2412943891.py:1: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chatllm([
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 chatllm([
#       2     SystemMessage(content="you are a comedian AI assistant"),
#       3     HumanMessage(content="please provide some comedy punch lines")
#       4 ])
#
# File c:\Users\Harshit Goswami\OneDrive\Langchain\Q-A-Chatbot_using_Langchain\venv\lib\site-packages\langchain_core\_api\deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# ...

# %% [markdown]
# ## Prompt Template + LLM +Output Parsers

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema import BaseOutputParser

# %%
class CommaSeperatedOutput(BaseOutputParser):
    def parse(self,text:str):
        return text.strip().split(",")

# %%
template="Your are a helpful assistant. When the user give any input , you should generate 5 words synonyms in a comma seperated list"
human_template="{text}"
chatpromt=ChatPromptTemplate.from_messages([
    ("system",template),
    ("human",human_template)
])

# %%
chain=chatpromt|chatllm|CommaSeperatedOutput()

# %%
chain.invoke({"text":"good"})
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 chain.invoke({"text":"good"})
#
# File c:\Users\Harshit Goswami\OneDrive\Langchain\Q-A-Chatbot_using_Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:3016, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3014             input = context.run(step.invoke, input, config, **kwargs)
#    3015         else:
# -> 3016             input = context.run(step.invoke, input, config)
#    3017 # finish the root run
#    3018 except BaseException as e:
#
# File c:\Users\Harshit Goswami\OneDrive\Langchain\Q-A-Chatbot_using_Langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
# ...
